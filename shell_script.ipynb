# %%
!#!/bin/sh
!
!# Author : Zara Ali
!# Copyright (c) Tutorialspoint.com
!# Script follows here:
!
# !echo "What is your name?"
# !read PERSON
# !echo "Hello, $PERSON"
# Out:
# What is your name?
# Rohan
# Hello,

# %%
# Out:
#   File "<ipython-input-3-b2862975b711>", line 1
#     print(!$date)
#           ^
# SyntaxError: invalid syntax
